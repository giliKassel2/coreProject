# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.8 kB ? eta -:--:--
#      -------------------------------------- 60.8/60.8 kB 803.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.9 MB 640.0 kB/s eta 0:00:21
#    ---------------------------------------- 0.0/12.9 MB 487.6 kB/s eta 0:00:27
#    ---------------------------------------- 0.1/12.9 MB 573.4 kB/s eta 0:00:23
#    ---------------------------------------- 0.1/12.9 MB 654.9 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/12.9 MB 652.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/12.9 MB 652.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/12.9 MB 652.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.1/12.9 MB 652.5 kB/s eta 0:00:20
# ...

# %%
import numpy as np

# %%
new_arr= np.random.randint(1, 50, size=(10))
new_arr
# Out:
# array([45, 35,  2, 11,  4, 45, 29, 25, 17, 46], dtype=int32)

# %%
new_arr2= np.random.randint(10, 100, size=(2,5))
new_arr2
# Out:
# array([[54, 32, 50, 25, 22],
#        [23, 86, 69, 31, 52]], dtype=int32)

# %%
np.size(new_arr)
# Out:
# 10

# %%
np.
